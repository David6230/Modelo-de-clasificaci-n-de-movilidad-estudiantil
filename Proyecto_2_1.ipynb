# %% [markdown]
# <a href="https://colab.research.google.com/github/David6230/Modelo-de-clasificaci-n-de-movilidad-estudiantil/blob/main/Proyecto_2_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Opciones de bases de datos para el proyecto.

# %%
import pandas as pd
import numpy as np

# %%
df_1 = pd.read_csv("/content/movilidad_estudiantil.csv", sep="|")
df_1.head()
# Out:
#    individuo fecha_ingreso provincia_estudio canton_estudio    sexo    etnia  \
# 0          1    2016-04-18         PICHINCHA          QUITO  HOMBRE  MESTIZO
# 1          2    2016-04-18         PICHINCHA          QUITO   MUJER  MESTIZO
# 2          3    2016-04-18         PICHINCHA          QUITO  HOMBRE  MESTIZO
# 3          4    2016-04-18         PICHINCHA          QUITO  HOMBRE  MESTIZO
# 4          5    2016-04-18         PICHINCHA          QUITO  HOMBRE  MESTIZO
#
#   nacionalidad discapacidad tipo_colegio     beca nivel_formacion_padre  \
# 0      ECUADOR      NINGUNA       FISCAL  NINGUNA               NO_SABE
# 1      ECUADOR      NINGUNA       FISCAL  NINGUNA               NO_SABE
# 2      ECUADOR      NINGUNA       FISCAL  NINGUNA               NO_SABE
# 3      ECUADOR      NINGUNA   PARTICULAR  NINGUNA               NO_SABE
# 4      ECUADOR      NINGUNA       FISCAL  NINGUNA               NO_SABE
#
#   nivel_formacion_madre  numero_hermanos  anio_inicio_periodo  \
# ...

# %% [markdown]
# # Primera opción: conjunto de datos 1
# ## 1) Fuente de datos
#
# La fuente de los datos es tomada de la página de datos abiertos tema educación.
#
# ## 2) Breve descripción de datos
#
# El conjunto de datos contiene información sobre estudiantes y su ingreso a diferentes instituciones de educación en las diferentes provincias a nivel nacional, además de variables macroeconómicas como el índice de escolaridad provincial, el número de instituciones de educación en su provincia de nacimiento y las brechas de acceso a la educación por provincia.
#
# ## 3) ¿Cuál es el objetivo?
#
# El objetivo que se plantea es determinar cuáles son los factores que inciden en la movilidad de un estudiante para acceder a una institución de educación en una provincia distinta a la de su nacimiento. Se considera a los estudiantes matriculados en las diferentes instituciones de educación a nivel nacional para el año 2016.
#
# El tratamiento de la información es cuantitativo, a través de estadísticas descriptivas y un análisis econométrico utilizando un modelo de regresión logística que busca determinar qué factores inciden en la desición de movilización de un estudiante.
#
# Para medir la movilidad se plantea como variable respuesta una variable binaria que adopta el valor de "1" si el estudiante entro a una institución de educación fuera de su provincia de nacimiento y "0" si el estudiante entró a una institución de educación en su provincia de nacimiento.
#
# ## 4) ¿Este es un problema de clasificación o regresión?
# Es un problema de clasificación.
#
# ## 5) ¿Cuántas características hay?
# Existen 16 características de los estudiantes y 3 características provinciales.
#
# ## 6) ¿Cuántas filas de datos hay?
# Existen 130.455 filas
#
# ## 7) ¿Qué retos, si es que hay alguno, prevén en la limpieza, exploración o modelización con este conjunto de datos
#
# Se debe hacer un buen tratamiento de la base de datos para poder obtener una buena predicción, ya que se busca modelar una regresión logística.
#
# La base de datos cuenta con variables missing, además de estandarización de variables y análisis de atípicos y consistencia.
#
# Hay que aplicar ingeniería de variables.
